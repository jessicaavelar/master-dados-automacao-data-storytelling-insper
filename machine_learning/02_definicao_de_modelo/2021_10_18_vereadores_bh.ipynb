# %% [markdown]
# *Notebook da aula 02 da disciplina de Machine Learning para jornalistas. Aqui temos a criação de um modelo preditivo para eleição de vereadores na cidade de Belo Horizonte a partir de dados disponibilizados pelo TSE.*
#
# O dados utilizados são da [base do TSE](https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1).
#
# Para o exemplo, foram utilizados os dados de 2020 do estado de São Paulo das bases de candidatos, bens e os resultados da eleição.

# %%
import pandas as pd
import numpy as np

# %%
# Importando as bases que serão utilizadas

base_cand = pd.read_csv('consulta_cand_2020_MG.csv',sep=';', encoding='latin1', decimal=",")
base_bens = pd.read_csv('bem_candidato_2020_MG.csv',sep=';', encoding='latin1', decimal=",")
base_result = pd.read_csv('votacao_candidato_munzona_2020_MG.csv',sep=';', encoding='latin1', decimal=",")

# %%
# Conhecendo as bases

list(base_cand.columns)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'NR_TURNO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'TP_ABRANGENCIA',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'CD_CARGO',
#  'DS_CARGO',
#  'SQ_CANDIDATO',
#  'NR_CANDIDATO',
#  'NM_CANDIDATO',
#  'NM_URNA_CANDIDATO',
#  'NM_SOCIAL_CANDIDATO',
#  'NR_CPF_CANDIDATO',
#  'NM_EMAIL',
#  'CD_SITUACAO_CANDIDATURA',
#  'DS_SITUACAO_CANDIDATURA',
#  'CD_DETALHE_SITUACAO_CAND',
#  'DS_DETALHE_SITUACAO_CAND',
#  'TP_AGREMIACAO',
#  'NR_PARTIDO',
#  'SG_PARTIDO',
#  'NM_PARTIDO',
#  'SQ_COLIGACAO',
#  'NM_COLIGACAO',
#  'DS_COMPOSICAO_COLIGACAO',
#  'CD_NACIONALIDADE',
#  'DS_NACIONALIDADE',
#  'SG_UF_NASCIMENTO',
#  'CD_MUNICIPIO_NASCIMENTO',
#  'NM_MUNICIPIO_NASCIMENTO',
#  'DT_NASCIMENTO',
#  'NR_IDADE_DATA_POSSE',
#  'NR_TITULO_ELEITORAL_CANDIDATO',
#  'CD_GENERO',
#  'DS_GENERO',
#  'CD_GRAU_INSTRUCAO',
#  'DS_GRAU_INSTRUCAO',
#  'CD_ESTADO_CIVIL',
#  'DS_ESTADO_CIVIL',
#  'CD_COR_RACA',
#  'DS_COR_RACA',
#  'CD_OCUPACAO',
#  'DS_OCUPACAO',
#  'VR_DESPESA_MAX_CAMPANHA',
#  'CD_SIT_TOT_TURNO',
#  'DS_SIT_TOT_TURNO',
#  'ST_REELEICAO',
#  'ST_DECLARAR_BENS',
#  'NR_PROTOCOLO_CANDIDATURA',
#  'NR_PROCESSO',
#  'CD_SITUACAO_CANDIDATO_PLEITO',
#  'DS_SITUACAO_CANDIDATO_PLEITO',
#  'CD_SITUACAO_CANDIDATO_URNA',
#  'DS_SITUACAO_CANDIDATO_URNA',
#  'ST_CANDIDATO_INSERIDO_URNA']

# %%
base_cand.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  24/10/2021   06:48:17         2020                2  ELEIÇÃO ORDINÁRIA
# 1  24/10/2021   06:48:17         2020                2  ELEIÇÃO ORDINÁRIA
# 2  24/10/2021   06:48:17         2020                2  ELEIÇÃO ORDINÁRIA
# 3  24/10/2021   06:48:17         2020                2  ELEIÇÃO ORDINÁRIA
# 4  24/10/2021   06:48:17         2020                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 1         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 2         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 3         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 4         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
#
#    ... DS_SIT_TOT_TURNO  ST_REELEICAO ST_DECLARAR_BENS  \
# 0  ...         SUPLENTE             N                N
# 1  ...         SUPLENTE             N                S
# 2  ...         SUPLENTE             N                S
# 3  ...         SUPLENTE             N                S
# 4  ...    ELEITO POR QP             S                S
#
#    NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 0                        -1  6002308020206130176
# 1                        -1  6001863620206130346
# 2                        -1  6002888120206130015
# 3                        -1  6001489120206130162
# 4                        -1  6001683920206130338
#
#    CD_SITUACAO_CANDIDATO_PLEITO  DS_SITUACAO_CANDIDATO_PLEITO  \
# 0                             2                      DEFERIDO
# 1                             2                      DEFERIDO
# 2                             2                      DEFERIDO
# 3                             2                      DEFERIDO
# 4                             2                      DEFERIDO
#
#   CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 0                          2                   DEFERIDO
# 1                          2                   DEFERIDO
# 2                          2                   DEFERIDO
# 3                          2                   DEFERIDO
# 4                          2                   DEFERIDO
#
#   ST_CANDIDATO_INSERIDO_URNA
# 0                        SIM
# 1                        SIM
# 2                        SIM
# 3                        SIM
# 4                        SIM
#
# [5 rows x 63 columns]

# %%
list(base_bens.columns)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'SQ_CANDIDATO',
#  'NR_ORDEM_CANDIDATO',
#  'CD_TIPO_BEM_CANDIDATO',
#  'DS_TIPO_BEM_CANDIDATO',
#  'DS_BEM_CANDIDATO',
#  'VR_BEM_CANDIDATO',
#  'DT_ULTIMA_ATUALIZACAO',
#  'HH_ULTIMA_ATUALIZACAO']

# %%
base_bens.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  24/10/2021   06:45:57         2020                2  Eleição Ordinária
# 1  24/10/2021   06:45:57         2020                2  Eleição Ordinária
# 2  24/10/2021   06:45:57         2020                2  Eleição Ordinária
# 3  24/10/2021   06:45:57         2020                2  Eleição Ordinária
# 4  24/10/2021   06:45:57         2020                2  Eleição Ordinária
#
#    CD_ELEICAO                DS_ELEICAO  DT_ELEICAO SG_UF  SG_UE    NM_UE  \
# 0         426  Eleições Municipais 2020  15/11/2020    MG  45519  GOUVEIA
# 1         426  Eleições Municipais 2020  15/11/2020    MG  45519  GOUVEIA
# 2         426  Eleições Municipais 2020  15/11/2020    MG  45519  GOUVEIA
# 3         426  Eleições Municipais 2020  15/11/2020    MG  45519  GOUVEIA
# 4         426  Eleições Municipais 2020  15/11/2020    MG  45519  GOUVEIA
#
#    SQ_CANDIDATO  NR_ORDEM_CANDIDATO  CD_TIPO_BEM_CANDIDATO  \
# 0  130000631754                   1                     39
# 1  130000631754                   2                     21
# 2  130000631754                   3                     63
# 3  130000631754                   4                     21
# 4  130000631754                   5                     21
#
#                                DS_TIPO_BEM_CANDIDATO  \
# 0                   Outras participações societárias
# 1  Veículo automotor terrestre: caminhão, automóv...
# 2               Dinheiro em espécie - moeda nacional
# 3  Veículo automotor terrestre: caminhão, automóv...
# 4  Veículo automotor terrestre: caminhão, automóv...
#
#                                     DS_BEM_CANDIDATO  VR_BEM_CANDIDATO  \
# 0  CAPITAL SOCIAL DA EMPRESA ANTONIO VICENTE DE S...           10000.0
# 1                           RENAULT DUSTER 2012/2012           45000.0
# 2                                               REAL           55000.0
# 3                  CAMINHÃO M.BENZ 710 ANO 2011/2011          100000.0
# 4                    CAMINHÃO M.BENZ L1316 1985/1986           60000.0
#
#   DT_ULTIMA_ATUALIZACAO HH_ULTIMA_ATUALIZACAO
# 0            15/11/2020              23:07:55
# 1            15/11/2020              23:07:55
# 2            15/11/2020              23:07:55
# 3            15/11/2020              23:07:55
# 4            15/11/2020              23:07:55

# %%
list(base_result.columns)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'NR_TURNO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'TP_ABRANGENCIA',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'CD_MUNICIPIO',
#  'NM_MUNICIPIO',
#  'NR_ZONA',
#  'CD_CARGO',
#  'DS_CARGO',
#  'SQ_CANDIDATO',
#  'NR_CANDIDATO',
#  'NM_CANDIDATO',
#  'NM_URNA_CANDIDATO',
#  'NM_SOCIAL_CANDIDATO',
#  'CD_SITUACAO_CANDIDATURA',
#  'DS_SITUACAO_CANDIDATURA',
#  'CD_DETALHE_SITUACAO_CAND',
#  'DS_DETALHE_SITUACAO_CAND',
#  'TP_AGREMIACAO',
#  'NR_PARTIDO',
#  'SG_PARTIDO',
#  'NM_PARTIDO',
#  'SQ_COLIGACAO',
#  'NM_COLIGACAO',
#  'DS_COMPOSICAO_COLIGACAO',
#  'CD_SIT_TOT_TURNO',
#  'DS_SIT_TOT_TURNO',
#  'ST_VOTO_EM_TRANSITO',
#  'QT_VOTOS_NOMINAIS']

# %%
base_result.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  23/10/2021   23:59:10         2020                2  Eleição Ordinária
# 1  23/10/2021   23:59:10         2020                2  Eleição Ordinária
# 2  23/10/2021   23:59:10         2020                2  Eleição Ordinária
# 3  23/10/2021   23:59:10         2020                2  Eleição Ordinária
# 4  23/10/2021   23:59:10         2020                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  ELEIÇÕES MUNICIPAIS 2020  15/11/2020              M
# 1         1         426  ELEIÇÕES MUNICIPAIS 2020  15/11/2020              M
# 2         1         426  ELEIÇÕES MUNICIPAIS 2020  15/11/2020              M
# 3         1         426  ELEIÇÕES MUNICIPAIS 2020  15/11/2020              M
# 4         1         426  ELEIÇÕES MUNICIPAIS 2020  15/11/2020              M
#
#    ... NR_PARTIDO  SG_PARTIDO                     NM_PARTIDO  SQ_COLIGACAO  \
# 0  ...         70      AVANTE                         AVANTE  130000112266
# 1  ...         40         PSB  Partido Socialista Brasileiro  130000118787
# 2  ...         70      AVANTE                         AVANTE  130000112266
# 3  ...         43          PV                  Partido Verde  130000058545
# 4  ...         65     PC do B    Partido Comunista do Brasil  130000119510
#
#       NM_COLIGACAO  DS_COMPOSICAO_COLIGACAO  CD_SIT_TOT_TURNO  \
# 0  PARTIDO ISOLADO                   AVANTE                 5
# 1  PARTIDO ISOLADO                      PSB                 4
# 2  PARTIDO ISOLADO                   AVANTE                 5
# 3  PARTIDO ISOLADO                       PV                 4
# 4  PARTIDO ISOLADO                  PC do B                 4
#
#   DS_SIT_TOT_TURNO  ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 0         SUPLENTE                    N                  7
# 1       NÃO ELEITO                    N                 10
# 2         SUPLENTE                    N                  2
# 3       NÃO ELEITO                    N                  5
# 4       NÃO ELEITO                    N                 18
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Limpando a base de dados
#
# O objetivo é separar as colunas que nos interessa, se o candidato foi eleito ou não, as variáveis explicativas do lado para construir o modelo.

# %%
# Selecionando as variáveis interessantes, o cargo e a cidade

candidatos = base_cand[["ANO_ELEICAO","SG_UF","NM_UE","DS_CARGO", "SQ_CANDIDATO", "NM_URNA_CANDIDATO",
                        "CD_SITUACAO_CANDIDATURA", "SG_PARTIDO","NR_IDADE_DATA_POSSE", "DS_GENERO", "DS_GRAU_INSTRUCAO",
                        "DS_ESTADO_CIVIL", "DS_COR_RACA", "DS_OCUPACAO", "VR_DESPESA_MAX_CAMPANHA", "ST_REELEICAO",
                        "ST_DECLARAR_BENS","ST_CANDIDATO_INSERIDO_URNA"]]
candidatos = candidatos[(candidatos["NM_UE"] == "BELO HORIZONTE") & (candidatos["DS_CARGO"] == "VEREADOR")]

# Agregando os bens de cada candidado em uma única linha, assim, temos o total de bens de cada um

bens = base_bens[["SQ_CANDIDATO", "VR_BEM_CANDIDATO"]]
bens = bens.groupby(["SQ_CANDIDATO"]).sum()

# Selecionando as variáveis de interesse e agregando os resultatos por candidato

resultados = base_result[["SQ_CANDIDATO", "DS_SIT_TOT_TURNO", "QT_VOTOS_NOMINAIS"]]
resultados_unique = resultados.drop_duplicates(subset = "SQ_CANDIDATO")
resultados_unique = resultados_unique[["SQ_CANDIDATO", "DS_SIT_TOT_TURNO"]]
votos = resultados[["SQ_CANDIDATO", "QT_VOTOS_NOMINAIS"]]
votos = resultados.groupby(["SQ_CANDIDATO"]).sum()

# %%
# Juntando todas as bases em uma só

juntando = candidatos.merge(bens, how = "left", left_on = "SQ_CANDIDATO", right_on = "SQ_CANDIDATO")
juntando = juntando.merge(resultados_unique, how = "left", left_on = "SQ_CANDIDATO", right_on = "SQ_CANDIDATO")
juntando = juntando.merge(votos, how = "left", left_on = "SQ_CANDIDATO", right_on = "SQ_CANDIDATO")

# Para o modelo, precisamos de uma variável binária onde eleito = 1 e não eleito = 0

juntando[["eleito"]] = np.where((juntando["DS_SIT_TOT_TURNO"]=="ELEITO POR MÉDIA") | (juntando["DS_SIT_TOT_TURNO"]=="ELEITO POR QP"), 1, 0)

# %%
# Excluindo as informações que faltam na declaração de bens

juntando.dropna(subset = ["VR_BEM_CANDIDATO"], inplace=True)
juntando.head()
# Out:
#    ANO_ELEICAO SG_UF           NM_UE  DS_CARGO  SQ_CANDIDATO  \
# 0         2020    MG  BELO HORIZONTE  VEREADOR  130000757380
# 2         2020    MG  BELO HORIZONTE  VEREADOR  130000842323
# 3         2020    MG  BELO HORIZONTE  VEREADOR  130000656836
# 5         2020    MG  BELO HORIZONTE  VEREADOR  130000757334
# 6         2020    MG  BELO HORIZONTE  VEREADOR  130001042177
#
#                 NM_URNA_CANDIDATO  CD_SITUACAO_CANDIDATURA     SG_PARTIDO  \
# 0                  BETH RODRIGUES                       12           REDE
# 2  POLLETO NEVES-PALHAÇO BISCOITO                       12             PL
# 3                     ROSA SANTOS                       12            PTC
# 5                   RONALDO VIANA                       12           REDE
# 6                   GIOVANI MATOS                       12  SOLIDARIEDADE
#
#    NR_IDADE_DATA_POSSE  DS_GENERO  ... DS_COR_RACA  \
# 0                   66   FEMININO  ...       PRETA
# 2                   63  MASCULINO  ...      BRANCA
# 3                   45   FEMININO  ...       PARDA
# 5                   60  MASCULINO  ...       PARDA
# 6                   55  MASCULINO  ...      BRANCA
#
#                                          DS_OCUPACAO VR_DESPESA_MAX_CAMPANHA  \
# 0               APOSENTADO (EXCETO SERVIDOR PÚBLICO)               692183.02
# 2  MOTORISTA DE VEÍCULOS DE TRANSPORTE COLETIVO D...               692183.02
# 3                                          VIGILANTE               692183.02
# 5                                          TERAPEUTA               692183.02
# 6                                         EMPRESÁRIO               692183.02
#
#   ST_REELEICAO ST_DECLARAR_BENS ST_CANDIDATO_INSERIDO_URNA VR_BEM_CANDIDATO  \
# 0            N                S                        SIM        250000.00
# 2            N                S                        SIM         22800.00
# 3            N                S                        SIM        140000.00
# 5            N                S                        SIM        332381.96
# 6            N                S                        SIM        250000.00
#
#   DS_SIT_TOT_TURNO  QT_VOTOS_NOMINAIS eleito
# 0         SUPLENTE               43.0      0
# 2         SUPLENTE              206.0      0
# 3         SUPLENTE               20.0      0
# 5         SUPLENTE             1641.0      0
# 6       NÃO ELEITO              993.0      0
#
# [5 rows x 22 columns]

# %% [markdown]
# ###  Ajustando a base de dados para o modelo

# %%
# Criando o dataset para o modelo - variáveis explicativas e variáveis respostas

var_resposta = juntando[["eleito"]]
var_explicativas = juntando[["SG_PARTIDO", "NR_IDADE_DATA_POSSE", "DS_GENERO", "DS_GRAU_INSTRUCAO", "DS_ESTADO_CIVIL", "DS_COR_RACA", "ST_REELEICAO", "VR_BEM_CANDIDATO"]]

# %%
var_resposta.head()
# Out:
#    eleito
# 0       0
# 2       0
# 3       0
# 5       0
# 6       0

# %%
var_explicativas.head()
# Out:
#       SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO        DS_GRAU_INSTRUCAO  \
# 0           REDE                   66   FEMININO        SUPERIOR COMPLETO
# 2             PL                   63  MASCULINO  ENSINO MÉDIO INCOMPLETO
# 3            PTC                   45   FEMININO    ENSINO MÉDIO COMPLETO
# 5           REDE                   60  MASCULINO        SUPERIOR COMPLETO
# 6  SOLIDARIEDADE                   55  MASCULINO        SUPERIOR COMPLETO
#
#   DS_ESTADO_CIVIL DS_COR_RACA ST_REELEICAO  VR_BEM_CANDIDATO
# 0       CASADO(A)       PRETA            N         250000.00
# 2       CASADO(A)      BRANCA            N          22800.00
# 3       CASADO(A)       PARDA            N         140000.00
# 5       CASADO(A)       PARDA            N         332381.96
# 6     SOLTEIRO(A)      BRANCA            N         250000.00

# %% [markdown]
# Temos muitas variáveis categóricas, precisamos transformá-las em variáveis numéricas.
# A variável numérica assume o valor 1 para uma categoria e 0 para outra, isso é chamado de dummy. Por exemplo: podemos ter uma dummy para o candidato que está tentando a reeleição - valor 1 - e quando isso não ocorrer - valor 0.

# %%
# Gerando Dummies

var_explicativas = pd.get_dummies(var_explicativas)
var_explicativas.head()
# Out:
#    NR_IDADE_DATA_POSSE  VR_BEM_CANDIDATO  SG_PARTIDO_AVANTE  \
# 0                   66         250000.00                  0
# 2                   63          22800.00                  0
# 3                   45         140000.00                  0
# 5                   60         332381.96                  0
# 6                   55         250000.00                  0
#
#    SG_PARTIDO_CIDADANIA  SG_PARTIDO_DC  SG_PARTIDO_DEM  SG_PARTIDO_MDB  \
# 0                     0              0               0               0
# 2                     0              0               0               0
# 3                     0              0               0               0
# 5                     0              0               0               0
# 6                     0              0               0               0
#
#    SG_PARTIDO_NOVO  SG_PARTIDO_PATRIOTA  SG_PARTIDO_PC do B  ...  \
# 0                0                    0                   0  ...
# 2                0                    0                   0  ...
# 3                0                    0                   0  ...
# 5                0                    0                   0  ...
# 6                0                    0                   0  ...
#
#    DS_ESTADO_CIVIL_SEPARADO(A) JUDICIALMENTE  DS_ESTADO_CIVIL_SOLTEIRO(A)  \
# 0                                          0                            0
# 2                                          0                            0
# 3                                          0                            0
# 5                                          0                            0
# 6                                          0                            1
#
#    DS_ESTADO_CIVIL_VIÚVO(A)  DS_COR_RACA_AMARELA  DS_COR_RACA_BRANCA  \
# 0                         0                    0                   0
# 2                         0                    0                   1
# 3                         0                    0                   0
# 5                         0                    0                   0
# 6                         0                    0                   1
#
#    DS_COR_RACA_NÃO INFORMADO  DS_COR_RACA_PARDA  DS_COR_RACA_PRETA  \
# 0                          0                  0                  1
# 2                          0                  0                  0
# 3                          0                  1                  0
# 5                          0                  1                  0
# 6                          0                  0                  0
#
#    ST_REELEICAO_N  ST_REELEICAO_S
# 0               1               0
# 2               1               0
# 3               1               0
# 5               1               0
# 6               1               0
#
# [5 rows x 54 columns]

# %% [markdown]
# ### Criando o modelo a partir da base de treinamento

# %%
from sklearn.linear_model import LogisticRegression

# Criando o modelo

logisticRegr = LogisticRegression()
model = logisticRegr.fit(var_explicativas, var_resposta.values.ravel())

# Criando as previsões a partir do modelo

predictions = logisticRegr.predict(var_explicativas)
predictions_prob = logisticRegr.predict_proba(var_explicativas)

predictions = pd.DataFrame(predictions, columns=["predito"])

predictions_prob = pd.DataFrame(predictions_prob, columns=["Prob_0", "Prob_1"])

predictions_prob.head()
# Out:
#      Prob_0    Prob_1
# 0  0.990238  0.009762
# 1  0.988678  0.011322
# 2  0.959300  0.040700
# 3  0.984813  0.015187
# 4  0.978950  0.021050

# %%
# Exportando os resultados para análise

analise = pd.concat([juntando.reset_index(drop=True), predictions_prob], axis=1)
analise.to_csv("analise_bh.csv", sep=";")
analise.head()
# Out:
#    ANO_ELEICAO SG_UF           NM_UE  DS_CARGO  SQ_CANDIDATO  \
# 0         2020    MG  BELO HORIZONTE  VEREADOR  130000757380
# 1         2020    MG  BELO HORIZONTE  VEREADOR  130000842323
# 2         2020    MG  BELO HORIZONTE  VEREADOR  130000656836
# 3         2020    MG  BELO HORIZONTE  VEREADOR  130000757334
# 4         2020    MG  BELO HORIZONTE  VEREADOR  130001042177
#
#                 NM_URNA_CANDIDATO  CD_SITUACAO_CANDIDATURA     SG_PARTIDO  \
# 0                  BETH RODRIGUES                       12           REDE
# 1  POLLETO NEVES-PALHAÇO BISCOITO                       12             PL
# 2                     ROSA SANTOS                       12            PTC
# 3                   RONALDO VIANA                       12           REDE
# 4                   GIOVANI MATOS                       12  SOLIDARIEDADE
#
#    NR_IDADE_DATA_POSSE  DS_GENERO  ... VR_DESPESA_MAX_CAMPANHA ST_REELEICAO  \
# 0                   66   FEMININO  ...               692183.02            N
# 1                   63  MASCULINO  ...               692183.02            N
# 2                   45   FEMININO  ...               692183.02            N
# 3                   60  MASCULINO  ...               692183.02            N
# 4                   55  MASCULINO  ...               692183.02            N
#
#   ST_DECLARAR_BENS ST_CANDIDATO_INSERIDO_URNA VR_BEM_CANDIDATO  \
# 0                S                        SIM        250000.00
# 1                S                        SIM         22800.00
# 2                S                        SIM        140000.00
# 3                S                        SIM        332381.96
# 4                S                        SIM        250000.00
#
#   DS_SIT_TOT_TURNO QT_VOTOS_NOMINAIS eleito    Prob_0    Prob_1
# 0         SUPLENTE              43.0      0  0.990238  0.009762
# 1         SUPLENTE             206.0      0  0.988678  0.011322
# 2         SUPLENTE              20.0      0  0.959300  0.040700
# 3         SUPLENTE            1641.0      0  0.984813  0.015187
# 4       NÃO ELEITO             993.0      0  0.978950  0.021050
#
# [5 rows x 24 columns]
