# %% [markdown]
# Instalando a biblioteca

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# !cd /content/twint && pip3 install . -r requirements.txt
# !pip install aiohttp==3.7.0

# %% [markdown]
# Fazendo a conexao pra salvar o arquivo no google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Exemplo

# %%
import twint
import nest_asyncio
nest_asyncio.apply()
import time

import os

timestr = time.strftime("%Y%m%d")

c = twint.Config()
c.Limit = 2000
c.Store_csv = True
c.Search = "vacinação", "pandemia", "vacinacao"
text_file = "/content/drive/My Drive/Insper/2º tri/01 - Mineração e análise de dados/Aula 01/vacinacao.csv"
c.Output = text_file
twint.run.Search(c)

# %% [markdown]
# Fazendo uma nuvem de palavras

# %%
# !pip install wordcloud
# !pip install pandas
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# Instalando mais bibliotecas que sao requisitos

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import pandas

# %% [markdown]
# Criando a nuvem de palavras

# %% [markdown]
# Apenas o texto dos Tuites

# %%
df = pandas.read_csv(text_file, delimiter=',')
df['tweet']
# Out:
# 0      acho ótima a forma como o bolsonaro tenta atra...
# 1      @Ferris_Charliel @wickedgmes_ @o_brno @DaniloD...
# 2      @luizcjandrade @OsmarTerra @geraldo1963 E quem...
# 3      FAKE NEWS - O presidente Jair Bolsonaro tem us...
# 4      @YugibearCReal @Hialley @monark Nossa quanto m...
#                              ...
# 984    @alepavanelli @ro_maju Meus 3 filhos nunca fre...
# 985    @StribelVirginia @Lorditaliano1 @JanainaDoBras...
# 986    @ferrari_arlene eu acho errado tirar o direito...
# 987    @JanainaDoBrasil Você consegue entender que a ...
# 988    @fatima_lessing @Samuel78195101 @tiago_veiga @...
# Name: tweet, Length: 989, dtype: object

# %%
  # Juntando todos tuites numa string
 
  tuites = ''
  for index, row in df.iterrows():
    tuites = tuites + row['tweet']
    
  # Montando a nuvem de palavras
  wordcloud = WordCloud().generate(tuites)
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
